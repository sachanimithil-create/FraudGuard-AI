# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv('/FraudGuard-AI/data/raw/creditcard.csv')

# %%
# Transaction Amount Distribution
plt.figure(figsize=(10,5))

sns.histplot(df["Amount"], bins=50, kde=True)

plt.title("Distribution of Transaction Amount")
plt.xlabel("Amount")
plt.ylabel("Frequency")

plt.show()

# %%
# Transaction Time Distribution
plt.figure(figsize=(10,5))

sns.histplot(df["Time"], bins=50)

plt.title("Transaction Time Distribution")

plt.show()

# %%
# Class Distribution
plt.figure(figsize=(6,4))

sns.countplot(x="Class", data=df)

plt.title("Fraud vs Genuine Transactions")

plt.show()

# %%
# Fraud Percentage
fraud_percentage = df["Class"].value_counts(normalize=True) * 100

print(fraud_percentage)
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
# Amount Distribution by Class
plt.figure(figsize=(10,5))

sns.boxplot(x="Class", y="Amount", data=df)

plt.title("Transaction Amount by Class")

plt.show()

# %%
# Statistics by Class

df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87

# %%
# Correlation Matrix

corr = df.corr()

plt.figure(figsize=(20,15))

sns.heatmap(corr,
            cmap="coolwarm",
            center=0)

plt.title("Correlation Matrix")

plt.show()

# %%
# Correlation with Target

corr_target = df.corr()["Class"].sort_values(ascending=False)

print(corr_target)
# Out:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012323
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326481
# Name: Class, dtype: float64

# %%
# Pair Plot

sample_df = df.sample(1000, random_state=42)

sns.pairplot(sample_df[["V1","V2","V3","Amount","Class"]],
             hue="Class")

plt.show()

# %%
# Amount Outliers

plt.figure(figsize=(10,5))

sns.boxplot(x=df["Amount"])

plt.title("Amount Outliers")

plt.show()

# %%
# Time Outliers

plt.figure(figsize=(10,5))

sns.boxplot(x=df["Time"])

plt.title("Time Distribution")

plt.show()

# %%
print("="*50)
print("EDA SUMMARY")
print("="*50)

print("1. Dataset is highly imbalanced.")
print("2. Fraud transactions are very rare.")
print("3. Amount is highly skewed.")
print("4. No missing values.")
print("5. Time and Amount require scaling.")
print("6. Features V1-V28 are already PCA-transformed.")
print("7. SMOTE will be applied during preprocessing.")
# Out:
# ...
# EDA SUMMARY
# ...
# 1. Dataset is highly imbalanced.
# 2. Fraud transactions are very rare.
# 3. Amount is highly skewed.
# 4. No missing values.
# 5. Time and Amount require scaling.
# 6. Features V1-V28 are already PCA-transformed.
# 7. SMOTE will be applied during preprocessing.
